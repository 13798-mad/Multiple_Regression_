# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Student_Performance.csv")

# %%
data.head(5)
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
sns.regplot(x="Previous Scores",y="Performance Index",data=data,color="green",scatter_kws={'color':'k'},line_kws={'color':'red'})
# Out:
# <Axes: xlabel='Previous Scores', ylabel='Performance Index'>

# %%
sns.lineplot(x="Hours Studied",y="Performance Index",data=data,color="red")
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Performance Index'>

# %%
sns.lineplot(x="Sleep Hours",y="Performance Index",data=data,color="red")
# Out:
# <Axes: xlabel='Sleep Hours', ylabel='Performance Index'>

# %%
sns.lineplot(x="Sample Question Papers Practiced",y="Performance Index",data=data,color="red")
# Out:
# <Axes: xlabel='Sample Question Papers Practiced', ylabel='Performance Index'>

# %%
EA= {'Yes': 1, 'No': 0}
data['Extracurricular Activities'] = data['Extracurricular Activities'].replace(EA)
# Out:
# /var/folders/km/41xdld515hq8qyv7nx3qq6n80000gn/T/ipykernel_1225/3042501373.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Extracurricular Activities'] = data['Extracurricular Activities'].replace(EA)

# %%
data.head(5)
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  int64
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 468.9 KB

# %%
data=data.drop(["Extracurricular Activities"],axis=1)

# %%
data.head(5)
# Out:
#    Hours Studied  Previous Scores  Sleep Hours  \
# 0              7               99            9
# 1              4               82            4
# 2              8               51            7
# 3              5               52            5
# 4              7               75            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Sleep Hours                       10000 non-null  int64
#  3   Sample Question Papers Practiced  10000 non-null  int64
#  4   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4)
# memory usage: 390.8 KB

# %%
data.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
data.corr()
# Out:
#                                   Hours Studied  Previous Scores  Sleep Hours  \
# Hours Studied                          1.000000        -0.012390     0.001245
# Previous Scores                       -0.012390         1.000000     0.005944
# Sleep Hours                            0.001245         0.005944     1.000000
# Sample Question Papers Practiced       0.017463         0.007888     0.003990
# Performance Index                      0.373730         0.915189     0.048106
#
#                                   Sample Question Papers Practiced  \
# Hours Studied                                             0.017463
# Previous Scores                                           0.007888
# Sleep Hours                                               0.003990
# Sample Question Papers Practiced                          1.000000
# Performance Index                                         0.043268
#
#                                   Performance Index
# ...

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
data=data.drop(["Sample Question Papers Practiced"],axis=1)
data=data.drop(["Sleep Hours"],axis=1)

# %%
data.head(5)
# Out:
#    Hours Studied  Previous Scores  Performance Index
# 0              7               99               91.0
# 1              4               82               65.0
# 2              8               51               45.0
# 3              5               52               36.0
# 4              7               75               66.0

# %%
x=data.drop(["Performance Index"],axis=1)
y=data["Performance Index"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([54.8191498 , 22.84514046, 47.30962885, ..., 16.74091117,
#        63.34604229, 45.66280587])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.985855014245765
